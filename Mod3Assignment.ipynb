# %%
things = ['mozzarella','cinderella','salmonella']
things[1] = things[1][0].upper() + things[1][1:]
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
things[0] = things[0].upper()

# %%
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %%
things[0] = things[0].upper()
print(things)
things.pop()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']
# ['MOZZARELLA', 'Cinderella']

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']
def get_odds():
    j = 0
    for i in range(10):
        if i % 2 != 0:
            j += 1
            yield i
        if j == 3:
            print(i)
get_odds()
# Out:
# <generator object get_odds at 0x0000029522B11630>
