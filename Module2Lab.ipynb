# %%
'''
Write a Python app that will accept student names and GPAs and test if the student qualifies for either the Dean's List or the Honor Roll. Your app will:
ask for and accept a student's last name.
quit processing student records if the last name entered is 'ZZZ'.
ask for and accept a student's first name.
ask for and accept the student's GPA as a float.
test if the student's GPA is 3.5 or greater and, if so, print a message saying that the student has made the Dean's List.
test if the student's GPA is 3.25 or greater and, if so, print a message saying that the studnet has made the Honor Roll.
Test your app using at least five students.
Your header comments need to contain
Your name
The file name for your app
A brief description of what your app will do
'''
# Out:
# "\nWrite a Python app that will accept student names and GPAs and test if the student qualifies for either the Dean's List or the Honor Roll. Your app will:\nask for and accept a student's last name.\nquit processing student records if the last name entered is 'ZZZ'.\nask for and accept a student's first name.\nask for and accept the student's GPA as a float.\ntest if the student's GPA is 3.5 or greater and, if so, print a message saying that the student has made the Dean's List.\ntest if the student's GPA is 3.25 or greater and, if so, print a message saying that the studnet has made the Honor Roll.\nTest your app using at least five students.\nYour header comments need to contain\nYour name\nThe file name for your app\nA brief description of what your app will do\n"

# %%
# Gavin Jackson
# Module2Lab
# This program will take in names and GPA's to determine whether students have either made Honor Roll or the Dean's List.
running = True
while running:
    print("Enter \"ZZZ\" to terminate the program\n")
    lastName = input("Enter your last name: \n")
    if lastName == "ZZZ":
        running = False
        break
    firstName = input("Enter a first name: \n")
    GPA = float(input("Enter your GPA as a decimal: \n"))
    if GPA >= 3.5:
        print(firstName + " has made it to the deans list!\n")

    elif GPA >= 3.25:
        print(firstName + " has made it to Honor Roll!\n")
    else:
        print(firstName + " didn't qualify for either status.\n")
print("Thank you for using this program!")
# Out:
# Enter "ZZZ" to terminate the program
# Enter your last name:
#  Jackson
# Enter a first name:
#  Gavin
# Enter your GPA as a decimal:
#  4.0
# Gavin has made it to the deans list!
#
# Enter "ZZZ" to terminate the program
# Enter your last name:
#  Gavin Jackson
# Enter a first name:
#  Jackson
# Enter your GPA as a decimal:
#  3.30
# Jackson has made it to Honor Roll!
#
# Enter "ZZZ" to terminate the program
# Enter your last name:
#  Jackson
# Enter a first name:
#  Gavin
# Enter your GPA as a decimal:
#  2.6
# Gavin didn't qualify for either status.
#
# Enter "ZZZ" to terminate the program
# Enter your last name:
#  Gavin Jackson
# Enter a first name:
#  jack
# Enter your GPA as a decimal:
#  5.0
# jack has made it to the deans list!
#
# Enter "ZZZ" to terminate the program
# Enter your last name:
#  t
# Enter a first name:
#  h
# Enter your GPA as a decimal:
#  1.0
# h didn't qualify for either status.
#
# Enter "ZZZ" to terminate the program
# Enter your last name:
#  ZZZ
# Thank you for using this program!
